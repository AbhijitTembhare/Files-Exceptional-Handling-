# %% [markdown]
# #Files & Exceptional Handling Assignment

# %% [markdown]
# 1.  **: What is the difference between interpreted and compiled languages?**
#     *   **:** Interpreted languages execute code line-by-line, while compiled languages are translated into machine code before execution.
#
# 2.  **: What is exception handling in Python?**
#     *   **:** Exception handling is a mechanism to manage errors that occur during program execution, preventing the program from crashing.
#
# 3.  **: What is the purpose of the finally block in exception handling?**
#     *   **:** The finally block contains code that is guaranteed to execute regardless of whether an exception was raised or handled.  It's used for cleanup tasks.
#
# 4.  **: What is logging in Python?**
#     *   **:** Logging is the process of recording events and messages during program execution, useful for debugging and monitoring.
#
# 5.  **: What is the significance of the `__del__` method in Python?**
#     *   **:** The `__del__` method (destructor) is called when an object is about to be garbage collected, but its use is generally discouraged.
#
# 6.  **: What is the difference between `import` and `from ... import` in Python?**
#     *   **:** `import module_name` imports the entire module, while `from module_name import name` imports specific items from the module.
#
# 7.  **: How can you handle multiple exceptions in Python?**
#     *   :You can use multiple `except` blocks, each designed to handle a different type of exception.
#
# 8.  **: What is the purpose of the `with` statement when handling files in Python?**
#     *   **:** The `with` statement ensures that resources (like files) are properly managed, automatically closing them even if exceptions occur.
#
# 9.  **: What is the difference between multithreading and multiprocessing?**
#     *   **:** Multithreading runs multiple threads within a single process, sharing the same memory. Multiprocessing runs multiple processes, each with its own memory space.
#
# 10. **: What are the advantages of using logging in a program?**
#     *   **:** Logging helps in debugging, monitoring program behavior, and identifying issues by providing a record of events.
#
# 11. **: What is memory management in Python?**
#     *   **:** Memory management in Python involves allocating and deallocating memory for objects during program execution.
#
# 12. **: What are the basic steps involved in exception handling in Python?**
#     *   **:** The basic steps are: `try` (enclose the code that might raise an exception), `except` (handle specific exceptions), and optionally `finally` (code that always executes).
#
# 13. **: Why is memory management important in Python?**
#     *   **:** Effective memory management prevents memory leaks, improves performance, and ensures program stability.
#
# 14. **: What is the role of `try` and `except` in exception handling?**
#     *   **:** `try` defines the block of code to be monitored for exceptions, and `except` specifies how to handle those exceptions.
#
# 15. **: How does Python's garbage collection system work?**
#     *   **:** Python uses automatic garbage collection to reclaim memory occupied by objects that are no longer referenced by the program.
#
# 16. **: What is the purpose of the `else` block in exception handling?**
#     *   **:** The `else` block is executed if no exceptions are raised within the corresponding `try` block.
#
# 17. **: What are the common logging levels in Python?**
#     *   **:** Common logging levels include DEBUG, INFO, WARNING, ERROR, and CRITICAL, representing different severities of messages.
#
# 18. **: What is the difference between `os.fork()` and `multiprocessing` in Python?**
#     *   **:** `os.fork()` is a lower-level, Unix-specific system call for creating processes. `multiprocessing` is a higher-level, cross-platform module for managing processes.
#
# 19. **: What is the importance of closing a file in Python?**
#     *   **:** Closing a file releases system resources, prevents data corruption, and ensures that changes are written to disk.
#
# 20. **: What is the difference between `file.read()` and `file.readline()` in Python?**
#     *   **:** `file.read()` reads the entire file content, while `file.readline()` reads one line at a time.
#
# 21. **: What is the logging module in Python used for?**
#     *   **A:** The logging module provides tools for flexible event and message logging in Python programs.
#
# 22.:  What is the `os` module in Python used for in file handling?**
#     *   :** The `os` module provides functions for interacting with the operating system, including file and directory operations.
#
# 23. **: What are the challenges associated with memory management in Python?**
#     *   **:** Challenges include memory leaks (unreleased memory), memory fragmentation, and the overhead of garbage collection.
#
# 24. **: How do you raise an exception manually in Python?**
#     *   **:** You can raise an exception manually using the `raise` keyword followed by the exception type and an optional message.  Example: `raise ValueError("Invalid input")`
#
# 25. **: Why is it important to use multithreading in certain applications?**
#     *   **:** Multithreading can improve performance in I/O-bound applications by allowing the program to perform other tasks while waiting for I/O operations to complete.

# %%
# 1. How can you open a file for writing in Python and write a string to it?
with open("filename.txt", "w") as f:
    f.write("your string")

# 2. Write a Python program to read the contents of a file and print each line.
with open("filename.txt", "r") as f:
    for line in f:
        print(line, end="")

# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?
try:
    with open("filename.txt", "r") as f:
        pass  # File operations here
except FileNotFoundError:
    print("File not found")

# 4. Write a Python script that reads from one file and writes its content to another file.
with open("source.txt", "r") as src, open("dest.txt", "w") as dest:
    dest.write(src.read())

# 5. How would you catch and handle division by zero error in Python?
try:
    result = x / y
except ZeroDivisionError:
    print("Cannot divide by zero")

# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.
import logging
logging.basicConfig(filename="my_log.txt", level=logging.ERROR)
try:
    result = x / y
except ZeroDivisionError:
    logging.error("Division by zero error")

# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
import logging
logging.info("Information")
logging.error("Error")
logging.warning("Warning")

# 8. Write a program to handle a file opening error using exception handling.
import logging
try:
    with open("filename.txt", "r") as f:
        pass  # File operations here
except FileNotFoundError:
    logging.error("File not found")

# 9. How can you read a file line by line and store its content in a list in Python?
with open("filename.txt", "r") as f:
    lines = f.readlines()
# or
with open("filename.txt", "r") as f:
    lines = list(f)

# 10. How can you append data to an existing file in Python?
with open("filename.txt", "a") as f:
    f.write("more data")

# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.
try:
    value = my_dict[key]
except KeyError:
    print("Key not found")

# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.
try:
    pass  # code that might raise exceptions
except FileNotFoundError:  # handle file not found
    pass
except KeyError:  # handle key error
    pass
except Exception as e:  # catch all other exceptions
    print(f"An error occurred: {e}")

# 13. How would you check if a file exists before attempting to read it in Python?
import os
if os.path.exists("filename.txt"):
    with open("filename.txt", "r") as f:
        pass  # File operations here

# 14. Write a program that uses the logging module to log both informational and error messages.
import logging
# ... (logging setup - see example #6)
try:
    # ... (file operations)
    logging.info("File operation successful")
except Exception as e:
    logging.error(f"An error occurred during file operation: {e}")

# 15. Write a Python program that prints the content of a file and handles the case when the file is empty.
import os
filename = "my_file.txt"

if os.path.exists(filename):
    if os.stat(filename).st_size == 0:
        print("File is empty.")
    else:
        with open(filename, 'r') as file:
            for line in file:
                print(line, end="")
else:
    print(f"File '{filename}' does not exist.")

# 16. Demonstrate how to use memory profiling to check the memory usage of a small program.
def my_function():
    # Your code here
    pass

# 17. Write a Python program to create and write a list of numbers to a file, one number per line.
numbers = [1, 2, 3]
with open("numbers.txt", "w") as f:
    for num in numbers:
        f.write(str(num) + "\n")

# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?
import logging
from logging.handlers import RotatingFileHandler
handler = RotatingFileHandler('my_log.txt', maxBytes=1024 * 1024, backupCount=5)
logging.basicConfig(handlers=[handler], level=logging.INFO)

# 19. Write a program that handles both `IndexError` and `KeyError` using a `try-except` block.
try:
    my_list[index]
    my_dict[key]
except (IndexError, KeyError):
    print("An IndexError or KeyError occurred.")

# 20. How would you open a file and read its contents using a context manager in Python?
with open("filename.txt", "r") as f:
    contents = f.read()

# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word.
word = "example"
count = 0
with open("filename.txt", "r") as f:
    for line in f:
        for w in line.split():
            if w == word:
                count += 1
print(f"The word '{word}' appears {count} times.")

# 22. How can you check if a file is empty before attempting to read its contents?
import os
if os.stat("filename.txt").st_size == 0:
    print("File is empty")

# 23. Write a Python program that writes to a log file when an error occurs during file handling.
import logging
try:
    with open("filename.txt", "r") as f:
        pass  # File operations
except Exception as e:
    logging.error(f"Error during file handling: {e}")
